# %% [markdown]
# ### Version

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.6.0
# ipykernel        : 6.30.1
# ipywidgets       : 8.1.7
# jupyter_client   : 8.6.3
# jupyter_core     : 5.8.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.4.10
# nbclient         : 0.10.2
# nbconvert        : 7.16.6
# nbformat         : 5.10.4
# notebook         : 7.4.7
# qtconsole        : not installed
# traitlets        : 5.14.3

# %% [markdown]
# ### Requirements

# %%
import subprocess

# Run pip install and capture output
result = subprocess.run(
    ["pip", "install", "-r", "../requirements.txt"], capture_output = True, text = True
)

# Clean up the output
shortened = result.stdout
shortened = shortened.replace(
    "c:\\users\\johnh\\appdata\\local\\programs\\python\\python312\\lib\\", ""
)
shortened = shortened.replace("from -r ../", "from ")
shortened = shortened.replace("->-r ../", " in ")
shortened = shortened.replace(".txt ", " ")
shortened = shortened.replace("(line", "(ln")
shortened = shortened.replace(")) (", " v")
shortened = shortened.replace("Requirement already satisfied", "Done already")

# Print the cleaned output
print(shortened)
# Out:
# Done already: jupyter in site-packages (from requirements (ln 3 v1.1.1)
# Done already: tqdm in site-packages (from requirements (ln 4 v4.67.1)
# Done already: numpy in site-packages (from requirements (ln 5 v1.26.4)
# Done already: pandas in site-packages (from requirements (ln 6 v2.2.2)
# Done already: matplotlib in site-packages (from requirements (ln 7 v3.10.6)
# Done already: seaborn in site-packages (from requirements (ln 8 v0.13.2)
# Done already: scikit-learn in site-packages (from requirements (ln 9 v1.7.2)
# Done already: pillow in site-packages (from requirements (ln 10 v11.1.0)
# Done already: opencv-python in site-packages (from requirements (ln 11 v4.11.0.86)
# Done already: pyyaml in site-packages (from requirements (ln 12 v6.0.3)
# Done already: torch in site-packages (from requirements (ln 16 v2.8.0)
# Done already: torchvision in site-packages (from requirements (ln 17 v0.23.0)
# Done already: torchaudio in site-packages (from requirements (ln 18 v2.8.0)
# Done already: timm in site-packages (from requirements (ln 19 v1.0.21)
# Done already: albumentations in site-packages (from requirements (ln 20 v2.0.8)
# Done already: pycocotools in site-packages (from requirements (ln 21 v2.0.10)
# Done already: rich in site-packages (from requirements (ln 25 v14.1.0)
# Done already: hydra-core in site-packages (from requirements (ln 26 v1.3.2)
# Done already: notebook in site-packages (from jupyter in requirements (ln 3 v7.4.7)
# Done already: jupyter-console in site-packages (from jupyter in requirements (ln 3 v6.6.3)
# Done already: nbconvert in site-packages (from jupyter in requirements (ln 3 v7.16.6)
# Done already: ipykernel in site-packages (from jupyter in requirements (ln 3 v6.30.1)
# Done already: ipywidgets in site-packages (from jupyter in requirements (ln 3 v8.1.7)
# Done already: jupyterlab in site-packages (from jupyter in requirements (ln 3 v4.4.10)
# Done already: colorama in site-packages (from tqdm in requirements (ln 4 v0.4.6)
# Done already: python-dateutil>=2.8.2 in site-packages (from pandas in requirements (ln 6 v2.9.0.post0)
# Done already: pytz>=2020.1 in site-packages (from pandas in requirements (ln 6 v2024.1)
# Done already: tzdata>=2022.7 in site-packages (from pandas in requirements (ln 6 v2025.2)
# Done already: contourpy>=1.0.1 in site-packages (from matplotlib in requirements (ln 7 v1.3.3)
# Done already: cycler>=0.10 in site-packages (from matplotlib in requirements (ln 7 v0.12.1)
# Done already: fonttools>=4.22.0 in site-packages (from matplotlib in requirements (ln 7 v4.60.1)
# Done already: kiwisolver>=1.3.1 in site-packages (from matplotlib in requirements (ln 7 v1.4.9)
# Done already: packaging>=20.0 in site-packages (from matplotlib in requirements (ln 7 v25.0)
# Done already: pyparsing>=2.3.1 in site-packages (from matplotlib in requirements (ln 7 v3.2.5)
# Done already: scipy>=1.8.0 in site-packages (from scikit-learn in requirements (ln 9 v1.13.1)
# Done already: joblib>=1.2.0 in site-packages (from scikit-learn in requirements (ln 9 v1.5.2)
# Done already: threadpoolctl>=3.1.0 in site-packages (from scikit-learn in requirements (ln 9 v3.6.0)
# Done already: filelock in site-packages (from torch in requirements (ln 16 v3.19.1)
# Done already: typing-extensions>=4.10.0 in site-packages (from torch in requirements (ln 16 v4.15.0)
# Done already: sympy>=1.13.3 in site-packages (from torch in requirements (ln 16 v1.14.0)
# Done already: networkx in site-packages (from torch in requirements (ln 16 v3.3)
# Done already: jinja2 in site-packages (from torch in requirements (ln 16 v3.1.6)
# Done already: fsspec in site-packages (from torch in requirements (ln 16 v2025.9.0)
# Done already: setuptools in site-packages (from torch in requirements (ln 16 v80.9.0)
# Done already: huggingface_hub in site-packages (from timm in requirements (ln 19 v0.35.3)
# Done already: safetensors in site-packages (from timm in requirements (ln 19 v0.6.2)
# Done already: pydantic>=2.9.2 in site-packages (from albumentations in requirements (ln 20 v2.11.9)
# Done already: albucore==0.0.24 in site-packages (from albumentations in requirements (ln 20 v0.0.24)
# Done already: opencv-python-headless>=4.9.0.80 in site-packages (from albumentations in requirements (ln 20 v4.10.0.84)
# Done already: stringzilla>=3.10.4 in site-packages (from albucore==0.0.24->albumentations in requirements (ln 20 v4.2.1)
# Done already: simsimd>=5.9.2 in site-packages (from albucore==0.0.24->albumentations in requirements (ln 20 v6.5.3)
# Done already: markdown-it-py>=2.2.0 in site-packages (from rich in requirements (ln 25 v4.0.0)
# Done already: pygments<3.0.0,>=2.13.0 in site-packages (from rich in requirements (ln 25 v2.19.2)
# Done already: omegaconf<2.4,>=2.2 in site-packages (from hydra-core in requirements (ln 26 v2.3.0)
# Done already: antlr4-python3-runtime==4.9.* in site-packages (from hydra-core in requirements (ln 26 v4.9.3)
# Done already: mdurl~=0.1 in site-packages (from markdown-it-py>=2.2.0->rich in requirements (ln 25 v0.1.2)
# Done already: annotated-types>=0.6.0 in site-packages (from pydantic>=2.9.2->albumentations in requirements (ln 20 v0.7.0)
# Done already: pydantic-core==2.33.2 in site-packages (from pydantic>=2.9.2->albumentations in requirements (ln 20 v2.33.2)
# Done already: typing-inspection>=0.4.0 in site-packages (from pydantic>=2.9.2->albumentations in requirements (ln 20 v0.4.2)
# Done already: six>=1.5 in site-packages (from python-dateutil>=2.8.2->pandas in requirements (ln 6 v1.17.0)
# Done already: mpmath<1.4,>=1.1.0 in site-packages (from sympy>=1.13.3->torch in requirements (ln 16 v1.3.0)
# Done already: requests in site-packages (from huggingface_hub->timm in requirements (ln 19 v2.32.3)
# Done already: comm>=0.1.1 in site-packages (from ipykernel->jupyter in requirements (ln 3 v0.2.3)
# Done already: debugpy>=1.6.5 in site-packages (from ipykernel->jupyter in requirements (ln 3 v1.8.17)
# Done already: ipython>=7.23.1 in site-packages (from ipykernel->jupyter in requirements (ln 3 v9.6.0)
# Done already: jupyter-client>=8.0.0 in site-packages (from ipykernel->jupyter in requirements (ln 3 v8.6.3)
# Done already: jupyter-core!=5.0.*,>=4.12 in site-packages (from ipykernel->jupyter in requirements (ln 3 v5.8.1)
# Done already: matplotlib-inline>=0.1 in site-packages (from ipykernel->jupyter in requirements (ln 3 v0.1.7)
# Done already: nest-asyncio>=1.4 in site-packages (from ipykernel->jupyter in requirements (ln 3 v1.6.0)
# Done already: psutil>=5.7 in site-packages (from ipykernel->jupyter in requirements (ln 3 v7.1.0)
# Done already: pyzmq>=25 in site-packages (from ipykernel->jupyter in requirements (ln 3 v27.1.0)
# Done already: tornado>=6.2 in site-packages (from ipykernel->jupyter in requirements (ln 3 v6.5.2)
# Done already: traitlets>=5.4.0 in site-packages (from ipykernel->jupyter in requirements (ln 3 v5.14.3)
# Done already: decorator in site-packages (from ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v5.2.1)
# Done already: ipython-pygments-lexers in site-packages (from ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v1.1.1)
# Done already: jedi>=0.16 in site-packages (from ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v0.19.2)
# Done already: prompt_toolkit<3.1.0,>=3.0.41 in site-packages (from ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v3.0.52)
# Done already: stack_data in site-packages (from ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v0.6.3)
# Done already: wcwidth in site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v0.2.14)
# Done already: parso<0.9.0,>=0.8.4 in site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v0.8.5)
# Done already: platformdirs>=2.5 in site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter in requirements (ln 3 v4.4.0)
# Done already: pywin32>=300 in site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter in requirements (ln 3 v311)
# Done already: widgetsnbextension~=4.0.14 in site-packages (from ipywidgets->jupyter in requirements (ln 3 v4.0.14)
# Done already: jupyterlab_widgets~=3.0.15 in site-packages (from ipywidgets->jupyter in requirements (ln 3 v3.0.15)
# Done already: MarkupSafe>=2.0 in site-packages (from jinja2->torch in requirements (ln 16 v3.0.3)
# Done already: async-lru>=1.0.0 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v2.0.5)
# Done already: httpx<1,>=0.25.0 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v0.28.1)
# Done already: jupyter-lsp>=2.0.0 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v2.3.0)
# Done already: jupyter-server<3,>=2.4.0 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v2.17.0)
# Done already: jupyterlab-server<3,>=2.27.1 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v2.27.3)
# Done already: notebook-shim>=0.2 in site-packages (from jupyterlab->jupyter in requirements (ln 3 v0.2.4)
# Done already: anyio in site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v4.11.0)
# Done already: certifi in site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v2025.8.3)
# Done already: httpcore==1.* in site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v1.0.9)
# Done already: idna in site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v3.7)
# Done already: h11>=0.16 in site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v0.16.0)
# Done already: argon2-cffi>=21.1 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v25.1.0)
# Done already: jupyter-events>=0.11.0 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.12.0)
# Done already: jupyter-server-terminals>=0.4.4 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.5.3)
# Done already: nbformat>=5.3.0 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v5.10.4)
# Done already: prometheus-client>=0.9 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.23.1)
# Done already: pywinpty>=2.0.1 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v3.0.0)
# Done already: send2trash>=1.8.2 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.8.3)
# Done already: terminado>=0.8.3 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.18.1)
# Done already: websocket-client>=1.7 in site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.8.0)
# Done already: babel>=2.10 in site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v2.17.0)
# Done already: json5>=0.9.0 in site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v0.12.1)
# Done already: jsonschema>=4.18.0 in site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v4.25.1)
# Done already: sniffio>=1.1 in site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter in requirements (ln 3 v1.3.1)
# Done already: argon2-cffi-bindings in site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v25.1.0)
# Done already: attrs>=22.2.0 in site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v25.4.0)
# Done already: jsonschema-specifications>=2023.03.6 in site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v2025.9.1)
# Done already: referencing>=0.28.4 in site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v0.36.2)
# Done already: rpds-py>=0.7.1 in site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter in requirements (ln 3 v0.27.1)
# Done already: python-json-logger>=2.0.4 in site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v3.3.0)
# Done already: rfc3339-validator in site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.1.4)
# Done already: rfc3986-validator>=0.1.1 in site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v0.1.1)
# Done already: fqdn in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.5.1)
# Done already: isoduration in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v20.11.0)
# Done already: jsonpointer>1.13 in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v3.0.0)
# Done already: rfc3987-syntax>=1.1.0 in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.1.0)
# Done already: uri-template in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.3.0)
# Done already: webcolors>=24.6.0 in site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v24.11.1)
# Done already: beautifulsoup4 in site-packages (from nbconvert->jupyter in requirements (ln 3 v4.14.2)
# Done already: bleach!=5.0.0 in site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter in requirements (ln 3 v6.2.0)
# Done already: defusedxml in site-packages (from nbconvert->jupyter in requirements (ln 3 v0.7.1)
# Done already: jupyterlab-pygments in site-packages (from nbconvert->jupyter in requirements (ln 3 v0.3.0)
# Done already: mistune<4,>=2.0.3 in site-packages (from nbconvert->jupyter in requirements (ln 3 v3.1.4)
# Done already: nbclient>=0.5.0 in site-packages (from nbconvert->jupyter in requirements (ln 3 v0.10.2)
# Done already: pandocfilters>=1.4.1 in site-packages (from nbconvert->jupyter in requirements (ln 3 v1.5.1)
# Done already: webencodings in site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter in requirements (ln 3 v0.5.1)
# Done already: tinycss2<1.5,>=1.1.0 in site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter in requirements (ln 3 v1.4.0)
# Done already: fastjsonschema>=2.15 in site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v2.21.2)
# Done already: charset-normalizer<4,>=2 in site-packages (from requests->huggingface_hub->timm in requirements (ln 19 v3.3.2)
# Done already: urllib3<3,>=1.21.1 in site-packages (from requests->huggingface_hub->timm in requirements (ln 19 v2.5.0)
# Done already: lark>=1.2.2 in site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.3.0)
# Done already: cffi>=1.0.1 in site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.17.1)
# Done already: pycparser in site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v2.23)
# Done already: soupsieve>1.2 in site-packages (from beautifulsoup4->nbconvert->jupyter in requirements (ln 3 v2.8)
# Done already: arrow>=0.15.0 in site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v1.3.0)
# Done already: types-python-dateutil>=2.8.10 in site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter in requirements (ln 3 v2.9.0.20250822)
# Done already: executing>=1.2.0 in site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v2.2.1)
# Done already: asttokens>=2.1.0 in site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v3.0.0)
# Done already: pure-eval in site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter in requirements (ln 3 v0.2.3)
